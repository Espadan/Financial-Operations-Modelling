# %%
from pandas import read_csv, DataFrame, Series, crosstab
import copy
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from plotly.tools import FigureFactory as FF
import plotly.plotly as py
from scipy import stats
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %% [markdown]
# ##  1. Считываем данные на фондовом рынке Франции за период 01.01.2010-31.12.2014

# %% [markdown]
# Данные по ценам активов:

# %%
datasetPrice = read_csv('adj_close.csv',';', index_col=['Date'], parse_dates=['Date'], dayfirst=True)
datasetPrice.head()
# Out:
#               ACA.PA  AF.PA      AI.PA     AIR.PA     ALO.PA    ALT.PA  \
# Date
# 2014-12-31  9.436186  7.964  83.949036  38.835205  26.640413  7.729390
# 2014-12-30  9.418646  7.781  83.255249  38.450142  26.437090  7.593544
# 2014-12-29  9.471265  7.570  84.357124  38.999569  26.600739  7.579762
# 2014-12-24  9.484418  7.615  83.867424  39.004257  26.690004  7.609294
# 2014-12-23  9.523882  7.600  84.561203  39.201492  26.784227  7.530544
#
#                 BN.PA     BNP.PA    BOL.PA     CNP.PA    ...         SAF.PA  \
# Date                                                     ...
# 2014-12-31  50.422443  43.844994  3.600600  12.709974    ...      49.272648
# 2014-12-30  50.005726  43.462265  3.609195  12.675447    ...      48.474667
# 2014-12-29  50.811371  44.592659  3.711387  12.800605    ...      49.003448
# 2014-12-24  50.302055  44.134270  3.642622  12.848079    ...      48.945763
# 2014-12-23  50.487263  44.147621  3.714252  12.809237    ...      48.849625
#
#                SCR.PA     SEV.PA    STM.PA      SU.PA      UG.PA     VIE.PA  \
# Date
# 2014-12-31  21.886477  12.653255  5.522931  56.327557   9.967134  13.119909
# 2014-12-30  21.691021  12.749699  5.511352  55.435383   9.908619  13.071004
# 2014-12-29  21.738800  13.223025  5.531840  57.052444  10.025649  13.315531
# 2014-12-24  21.882133  13.131026  5.514024  56.597065  10.035402  13.257733
# 2014-12-23  21.834356  13.135383  5.515805  56.931629  10.064660  13.248840
#
#                VIV.PA      VK.PA      ZC.PA
# Date
# 2014-12-31  16.700682  12.890471  26.976074
# 2014-12-30  16.664356  12.791224  26.454145
# 2014-12-29  16.813686  12.847963  27.106558
# 2014-12-24  16.781399  12.893298  26.710278
# 2014-12-23  16.789471  13.119877  27.043732
#
# [5 rows x 32 columns]

# %%
datasetPrice.shape
# Out:
# (1278, 32)

# %%
datasetPrice.describe()
# Out:
#             ACA.PA        AF.PA        AI.PA       AIR.PA       ALO.PA  \
# count  1278.000000  1278.000000  1278.000000  1278.000000  1278.000000
# mean      7.145693     8.291621    62.732587    28.991761    29.762124
# std       2.321406     2.912135    10.249356    12.387206     6.124620
# min       2.453026     3.055000    40.058216    12.046185    18.656223
# 25%       5.134587     6.166250    55.133083    18.520649    25.685252
# 50%       7.582931     7.887500    61.556273    24.866395    27.811202
# 75%       9.260732    10.784622    70.906448    41.336655    33.951103
# max      10.633248    15.115000    84.561203    52.870171    47.942841
#
#             ALT.PA        BN.PA       BNP.PA       BOL.PA       CNP.PA  \
# count  1278.000000  1278.000000  1278.000000  1278.000000  1278.000000
# mean      5.006874    43.547213    37.767783     0.721650     9.756001
# std       1.599598     5.363249     7.801001     1.125767     1.984843
# min       2.526916    32.518452    18.413811    -0.000304     5.814239
# 25%       3.656005    38.816887    32.943174     0.000002     8.339084
# 50%       4.978034    43.582254    39.317871     0.004208     9.415104
# 75%       6.014591    48.073307    43.329991     1.633776    11.149124
# max       8.311160    54.371136    52.604595     4.488811    13.996077
#
#           ...            SAF.PA       SCR.PA       SEV.PA       STM.PA  \
# count     ...       1278.000000  1278.000000  1278.000000  1278.000000
# mean      ...         29.893019    16.093271     9.561694     4.598480
# std       ...         11.261199     3.693069     1.869540     0.917177
# min       ...         11.785363    10.297086     6.205043     2.698773
# 25%       ...         21.172921    12.899205     7.834943     3.778264
# 50%       ...         25.419647    15.100245     9.827498     4.662156
# 75%       ...         41.743590    20.225273    10.969355     5.363392
# max       ...         51.054699    22.498896    13.516711     6.576987
#
#              SU.PA        UG.PA       VIE.PA       VIV.PA        VK.PA  \
# count  1278.000000  1278.000000  1278.000000  1278.000000  1278.000000
# mean     46.029131    11.134263    10.943169    12.130337    25.954124
# std       9.582489     5.027413     3.371193     1.935587     7.637356
# min      27.444208     3.546086     5.789892     7.996094    12.213279
# 25%      37.692819     7.296257     7.706368    10.736920    20.411819
# 50%      45.994659    10.123371    10.973292    11.713642    22.973320
# 75%      54.703499    14.606139    14.074033    13.227834    33.240431
# max      66.327309    22.400208    17.301737    16.813686    42.931267
#
#              ZC.PA
# count  1278.000000
# mean     14.038548
# std       6.900058
# min       3.382692
# 25%       7.927960
# 50%      13.072125
# 75%      21.220226
# max      27.106558
#
# [8 rows x 32 columns]

# %% [markdown]
# Данные по объемам продаж:

# %%
dataVol = read_csv('volume.csv',';', index_col=['Date'], parse_dates=['Date'], dayfirst=True)
dataVol.head()
# Out:
#                ACA.PA      AF.PA     AI.PA     AIR.PA    ALO.PA    ALT.PA  \
# Date
# 2014-12-31   888975.0  1511725.0  133543.0   511732.0  141348.0  119155.0
# 2014-12-30  2449882.0  2564957.0  567616.0  1368751.0  435896.0  155408.0
# 2014-12-29  4153832.0  2140022.0  537006.0  1927679.0  618952.0  203608.0
# 2014-12-24   863429.0  1373307.0  164417.0   404444.0  224628.0   86273.0
# 2014-12-23  5039349.0  3347441.0  736029.0  2216026.0  950584.0  420549.0
#
#                 BN.PA     BNP.PA     BOL.PA    CNP.PA    ...       SAF.PA  \
# Date                                                     ...
# 2014-12-31   239094.0   558150.0  1242798.0   43324.0    ...     230297.0
# 2014-12-30   878946.0  2150482.0  1408513.0  147658.0    ...     288978.0
# 2014-12-29  1066493.0  3232746.0  1122986.0  172014.0    ...     433884.0
# 2014-12-24   202732.0   559273.0   415335.0   26927.0    ...      98327.0
# 2014-12-23  1310296.0  2516632.0  1336633.0  143621.0    ...     382269.0
#
#               SCR.PA     SEV.PA     STM.PA      SU.PA      UG.PA     VIE.PA  \
# Date
# 2014-12-31  123226.0   745335.0   214801.0   341798.0   590572.0   494483.0
# 2014-12-30  162863.0  1067161.0   718364.0  1137138.0   959375.0  1270241.0
# 2014-12-29  237515.0   716661.0  1124315.0   913357.0  1578524.0  1290817.0
# 2014-12-24   61713.0   325983.0   186496.0   228640.0   310706.0   425491.0
# 2014-12-23  244863.0   865849.0  1027800.0  1200212.0  1781274.0  1311131.0
#
#                VIV.PA      VK.PA     ZC.PA
# Date
# 2014-12-31   819050.0   304312.0  149132.0
# 2014-12-30  2403460.0   909153.0  267402.0
# 2014-12-29  3668598.0   878490.0  277561.0
# 2014-12-24   797850.0   391927.0   77442.0
# 2014-12-23  3507740.0  1066202.0  367371.0
#
# [5 rows x 32 columns]

# %%
dataVol.shape
# Out:
# (1278, 32)

# %%
dataVol.describe()
# Out:
#              ACA.PA         AF.PA         AI.PA        AIR.PA        ALO.PA  \
# count  1.278000e+03  1.278000e+03  1.278000e+03  1.278000e+03  1.278000e+03
# mean   1.030918e+07  3.439797e+06  1.094719e+06  2.493911e+06  1.827917e+06
# std    6.503672e+06  1.960640e+06  4.946141e+05  1.724140e+06  1.449502e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.927207e+06  2.127137e+06  7.827015e+05  1.635894e+06  1.142029e+06
# 50%    8.616410e+06  3.028251e+06  1.014046e+06  2.134117e+06  1.557230e+06
# 75%    1.268375e+07  4.146631e+06  1.280372e+06  2.828130e+06  2.095136e+06
# max    5.648092e+07  1.589568e+07  4.854700e+06  2.689999e+07  2.807808e+07
#
#              ALT.PA         BN.PA        BNP.PA        BOL.PA        CNP.PA  \
# count  1.278000e+03  1.278000e+03  1.278000e+03  1.278000e+03  1.278000e+03
# mean   5.469555e+05  2.004647e+06  5.327900e+06  9.022292e+05  3.902902e+05
# std    4.480377e+05  9.254466e+05  2.821775e+06  2.818170e+06  2.213097e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.843998e+05  1.429867e+06  3.482120e+06  3.011000e+05  2.379712e+05
# 50%    4.283510e+05  1.811746e+06  4.563234e+06  4.760500e+05  3.437520e+05
# 75%    6.454162e+05  2.377168e+06  6.342410e+06  8.513250e+05  4.887840e+05
# max    4.485468e+06  9.557007e+06  2.417537e+07  6.954300e+07  2.195310e+06
#
#            ...             SAF.PA        SCR.PA        SEV.PA        STM.PA  \
# count      ...       1.278000e+03  1.278000e+03  1.278000e+03  1.278000e+03
# mean       ...       9.901008e+05  4.308482e+05  1.269311e+06  4.023840e+06
# std        ...       5.914316e+05  2.871684e+05  7.023945e+05  2.257299e+06
# min        ...       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        ...       6.400758e+05  2.755382e+05  8.375498e+05  2.491714e+06
# 50%        ...       8.567765e+05  3.738190e+05  1.117151e+06  3.615976e+06
# 75%        ...       1.206488e+06  5.102512e+05  1.527465e+06  5.013608e+06
# max        ...       8.382004e+06  5.430171e+06  1.049614e+07  2.242053e+07
#
#               SU.PA         UG.PA        VIE.PA        VIV.PA         VK.PA  \
# count  1.278000e+03  1.278000e+03  1.278000e+03  1.278000e+03  1.278000e+03
# mean   1.891772e+06  4.665065e+06  2.868343e+06  5.248743e+06  1.321659e+06
# std    8.903233e+05  3.272163e+06  1.716616e+06  2.471767e+06  8.630662e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.312834e+06  2.645893e+06  1.733517e+06  3.699588e+06  8.504518e+05
# 50%    1.700461e+06  3.713463e+06  2.461460e+06  4.781941e+06  1.119864e+06
# 75%    2.235526e+06  5.572245e+06  3.509276e+06  6.205259e+06  1.537514e+06
# max    8.564448e+06  3.692675e+07  1.779603e+07  3.210260e+07  1.375391e+07
#
#               ZC.PA
# count  1.278000e+03
# mean   7.727000e+05
# std    5.693986e+05
# min    0.000000e+00
# 25%    4.670802e+05
# 50%    6.381875e+05
# 75%    9.156225e+05
# max    9.824035e+06
#
# [8 rows x 32 columns]

# %% [markdown]
# # 2. Преобразуем данные по ценам в данные по доходности

# %% [markdown]
# ## используя *логарифмическую* доходность

# %%
def log_profitability(dataS):
    dataSNew = copy.copy(dataS)
    for column in range(0,dataS.shape[1]):
        for index in range(0,(dataS.shape[0])-1):
            dataSNew.iloc[index][column] = np.log(dataS.iloc[index+1][column]/dataS.iloc[index][column])
    dataSNew.drop(dataSNew.tail(1).index,inplace=True)
    return dataSNew

# %%
dataProb = log_profitability(datasetPrice)
dataProb.head()
# Out:
# C:\Users\maks_\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning:
#
# invalid value encountered in log
#               ACA.PA     AF.PA     AI.PA    AIR.PA    ALO.PA    ALT.PA  \
# Date
# 2014-12-31 -0.001861 -0.023247 -0.008299 -0.009965 -0.007661 -0.017732
# 2014-12-30  0.005571 -0.027492  0.013148  0.014188  0.006171 -0.001817
# 2014-12-29  0.001388  0.005927 -0.005822  0.000120  0.003350  0.003889
# 2014-12-24  0.004152 -0.001972  0.008238  0.005044  0.003524 -0.010403
# 2014-12-23 -0.018119 -0.023834 -0.013606 -0.006490 -0.019066  0.003784
#
#                BN.PA    BNP.PA    BOL.PA    CNP.PA    ...       SAF.PA  \
# Date                                                  ...
# 2014-12-31 -0.008299 -0.008767  0.002384 -0.002720    ...    -0.016328
# 2014-12-30  0.015983  0.025676  0.027921  0.009826    ...     0.010849
# 2014-12-29 -0.010074 -0.010333 -0.018702  0.003702    ...    -0.001178
# 2014-12-24  0.003675  0.000302  0.019474 -0.003028    ...    -0.001966
# 2014-12-23 -0.002755 -0.018209  0.015817 -0.003375    ...    -0.009691
#
#               SCR.PA    SEV.PA    STM.PA     SU.PA     UG.PA    VIE.PA  \
# Date
# 2014-12-31 -0.008971  0.007593 -0.002099 -0.015966 -0.005888 -0.003735
# 2014-12-30  0.002200  0.036452  0.003711  0.028753  0.011742  0.018535
# 2014-12-29  0.006572 -0.006982 -0.003226 -0.008014  0.000972 -0.004350
# 2014-12-24 -0.002186  0.000332  0.000323  0.005894  0.002911 -0.000671
# 2014-12-23 -0.009594 -0.012084  0.002258 -0.021449 -0.015133 -0.007748
#
#               VIV.PA     VK.PA     ZC.PA
# Date
# 2014-12-31 -0.002177 -0.007729 -0.019537
# 2014-12-30  0.008921  0.004426  0.024363
# 2014-12-29 -0.001922  0.003522 -0.014727
# 2014-12-24  0.000481  0.017421  0.012407
# 2014-12-23 -0.016726 -0.032253 -0.010058
#
# [5 rows x 32 columns]

# %% [markdown]
# Выгружаем данные в файл

# %%
dataProb.dropna(axis=1, inplace=True)
dataProb.to_csv(path_or_buf='dataProbability.csv', sep=';')

# %% [markdown]
# # 3-4. Проверка данных на значения повторной выборки из некоторого распределения

# %% [markdown]
# ### Проведем анализ для конкретной компании

# %% [markdown]
# ##### Анализ по доходности:

# %%
company = dataProb["FP.PA"]
company
# Out:
# Date
# 2014-12-31    0.000353
# 2014-12-30    0.028050
# 2014-12-29   -0.002976
# 2014-12-24    0.002976
# 2014-12-23   -0.020905
# 2014-12-22    0.000467
# 2014-12-19   -0.000700
# 2014-12-18   -0.023266
# 2014-12-17   -0.034400
# 2014-12-16   -0.026568
# 2014-12-15    0.028915
# 2014-12-12    0.034291
# 2014-12-11   -0.000588
# 2014-12-10    0.015972
# 2014-12-09    0.025240
# 2014-12-08    0.018991
# 2014-12-05   -0.015164
# 2014-12-04    0.031408
# 2014-12-03    0.004995
# 2014-12-02   -0.033487
# 2014-12-01    0.007922
# 2014-11-28    0.020025
# 2014-11-27    0.041292
# 2014-11-26   -0.003141
# 2014-11-25    0.015915
# 2014-11-24    0.001753
# 2014-11-21   -0.039505
# 2014-11-20   -0.003220
# 2014-11-19    0.000537
# 2014-11-18   -0.010587
#                 ...
# 2010-02-15   -0.001920
# 2010-02-12   -0.001924
# 2010-02-11   -0.015158
# 2010-02-10   -0.009577
# 2010-02-09    0.008843
# 2010-02-08   -0.018761
# 2010-02-05    0.035255
# 2010-02-04    0.018353
# 2010-02-03    0.002595
# 2010-02-02   -0.006025
# 2010-02-01   -0.003442
# 2010-01-29   -0.020057
# 2010-01-28    0.026221
# 2010-01-27    0.013498
# 2010-01-26   -0.003386
# 2010-01-25    0.010821
# 2010-01-22    0.014818
# 2010-01-21    0.012240
# 2010-01-20    0.014981
# 2010-01-19   -0.011607
# 2010-01-18   -0.016640
# 2010-01-15    0.024021
# 2010-01-14    0.006331
# 2010-01-13    0.010903
# 2010-01-12    0.013274
# 2010-01-11   -0.005419
# 2010-01-08   -0.001087
# 2010-01-07   -0.001742
# 2010-01-06   -0.000655
# 2010-01-05   -0.001200
# Name: FP.PA, Length: 1277, dtype: float64

# %%
company.plot(figsize=(12,6))

# %%
company.resample('6W', how='mean').plot(figsize=(12,6))
# Out:
# C:\Users\maks_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
# how in .resample() is deprecated
# the new syntax is .resample(...).mean()

# %%
company.hist()

# %%
probByYear = DataFrame()
a = company['2010']
a.drop(a.head(1).index,inplace=True)
probByYear['2010'] = a.values
a = company['2011']
a.drop(a.head(3).index,inplace=True)
probByYear['2011'] = a.values
a = company['2012']
probByYear['2012'] = a.values
a = company['2013']
a.drop(a.head(1).index,inplace=True)
probByYear['2013'] = a.values
a = company['2014']
a.drop(a.head(2).index,inplace=True)
probByYear['2014'] = a.values
probByYear
# Out:
#          2010      2011      2012      2013      2014
# 0   -0.012535 -0.005292  0.015429  0.003940 -0.002976
# 1   -0.001000 -0.021056 -0.007876 -0.011300  0.002976
# 2    0.012671 -0.010363 -0.006141 -0.000227 -0.020905
# 3    0.000123 -0.011011  0.006013 -0.005471  0.000467
# 4    0.000987 -0.013732 -0.003706 -0.013230 -0.000700
# 5   -0.014782 -0.006593  0.002174 -0.015993 -0.023266
# 6   -0.004641  0.019614 -0.006922 -0.013148 -0.034400
# 7    0.003389 -0.000532  0.006567  0.005114 -0.026568
# 8    0.000376  0.024586 -0.001512 -0.028394  0.028915
# 9    0.004249 -0.011757 -0.008992  0.005160  0.034291
# 10  -0.008140  0.020936 -0.017193  0.003942 -0.000588
# 11  -0.013163 -0.024754 -0.009362  0.007364  0.015972
# 12   0.004449  0.023724  0.008844  0.016665  0.025240
# 13  -0.007639 -0.004260 -0.001166 -0.000932  0.018991
# 14  -0.002816  0.002971 -0.001167 -0.008423 -0.015164
# 15  -0.014850 -0.004006  0.001297  0.015388  0.031408
# 16  -0.009805 -0.007931 -0.002596  0.011617  0.004995
# 17  -0.000657  0.000783  0.002337  0.016220 -0.033487
# 18  -0.010971 -0.028443 -0.008202  0.003482  0.007922
# 19  -0.008140 -0.006732 -0.007347 -0.000785  0.020025
# 20  -0.005779 -0.036318  0.011782  0.002689  0.041292
# 21   0.016971 -0.024105  0.004674 -0.002240 -0.003141
# 22   0.006208  0.013683 -0.007672  0.004476  0.015915
# 23  -0.001186  0.014336 -0.002222  0.002230  0.001753
# 24  -0.004095  0.005289  0.000000 -0.009402 -0.039505
# 25   0.016412  0.029812 -0.000131 -0.002477 -0.003220
# 26   0.010235  0.008586 -0.032986 -0.003275  0.000537
# 27   0.005912  0.007320  0.012231  0.010240 -0.010587
# 28  -0.010952 -0.014291  0.002268 -0.009449 -0.010151
# 29  -0.003764  0.011502  0.012319 -0.004985 -0.001647
# ..        ...       ...       ...       ...       ...
# 224 -0.001920  0.000690  0.013827 -0.005228 -0.009477
# 225 -0.001924 -0.010986 -0.006829  0.005749 -0.014793
# 226 -0.015158  0.014545  0.001712  0.000651  0.005342
# 227 -0.009577 -0.001032 -0.000733  0.012678 -0.011414
# 228  0.008843 -0.001492  0.002320  0.014168 -0.019039
# 229 -0.018761  0.000689 -0.002687 -0.011472 -0.005867
# 230  0.035255  0.010280 -0.005887  0.029310  0.003118
# 231  0.018353  0.001817 -0.006046 -0.005743  0.013674
# 232  0.002595 -0.031456 -0.014835  0.017132  0.012790
# 233 -0.006025 -0.009172  0.006884 -0.012012 -0.012317
# 234 -0.003442  0.020810  0.012519 -0.016074  0.009047
# 235 -0.020057 -0.004988 -0.006426  0.008321 -0.008694
# 236  0.026221 -0.008876  0.002229 -0.002262  0.011847
# 237  0.013498  0.006664 -0.010445 -0.007959  0.023964
# 238 -0.003386 -0.008896 -0.003757  0.001774  0.008502
# 239  0.010821 -0.013733  0.014697 -0.001774 -0.003166
# 240  0.014818  0.006061 -0.008942 -0.002794  0.005195
# 241  0.012240  0.007084  0.004232  0.010124 -0.006329
# 242  0.014981 -0.008151 -0.019189  0.004648 -0.009225
# 243 -0.011607  0.005795 -0.011974 -0.004145  0.004680
# 244 -0.016640 -0.009479  0.000896 -0.003025 -0.005367
# 245  0.024021 -0.006210  0.020907 -0.003161 -0.014183
# 246  0.006331 -0.016913  0.014070  0.001645  0.012234
# 247  0.010903 -0.008565 -0.011940 -0.000506 -0.005522
# 248  0.013274  0.012941  0.000750 -0.003675  0.004603
# 249 -0.005419  0.007974 -0.003256 -0.005857  0.009713
# 250 -0.001087 -0.006277  0.006876  0.016841 -0.010747
# 251 -0.001742 -0.003883  0.007694  0.000879  0.008698
# 252 -0.000655 -0.013216 -0.011063  0.003006 -0.002967
# 253 -0.001200 -0.011647 -0.012579 -0.027003  0.017671
#
# [254 rows x 5 columns]

# %%
corr = probByYear.corr(method='pearson')
corr
# Out:
#           2010      2011      2012      2013      2014
# 2010  1.000000  0.008748  0.016430 -0.018088 -0.077625
# 2011  0.008748  1.000000 -0.017455 -0.016077 -0.039236
# 2012  0.016430 -0.017455  1.000000 -0.082598 -0.075416
# 2013 -0.018088 -0.016077 -0.082598  1.000000 -0.056272
# 2014 -0.077625 -0.039236 -0.075416 -0.056272  1.000000

# %%
plt.figure(figsize = (5,5))
sns.heatmap(corr, annot=True, fmt=".4f", center=0);

# %%
corrUniq = np.zeros(10)
corrUniq[0] = corr['2010']['2011']
corrUniq[1] = corr['2010']['2012']
corrUniq[2] = corr['2010']['2013']
corrUniq[3] = corr['2010']['2014']
corrUniq[4] = corr['2011']['2012']
corrUniq[5] = corr['2011']['2013']
corrUniq[6] = corr['2011']['2014']
corrUniq[7] = corr['2012']['2013']
corrUniq[8] = corr['2012']['2014']
corrUniq[9] = corr['2013']['2014']
corrUniq
# Out:
# array([ 0.00874816,  0.01642956, -0.01808797, -0.0776247 , -0.01745461,
#        -0.0160773 , -0.03923634, -0.08259766, -0.07541616, -0.05627214])

# %%
corrUniq.mean()
# Out:
# -0.035758915294563133

# %%
statistic = np.zeros(10)
statistic[0] = stats.ks_2samp(probByYear['2010'], probByYear['2011']).statistic
statistic[1] = stats.ks_2samp(probByYear['2010'], probByYear['2012']).statistic
statistic[2] = stats.ks_2samp(probByYear['2010'], probByYear['2013']).statistic
statistic[3] = stats.ks_2samp(probByYear['2010'], probByYear['2014']).statistic
statistic[4] = stats.ks_2samp(probByYear['2011'], probByYear['2012']).statistic
statistic[5] = stats.ks_2samp(probByYear['2011'], probByYear['2013']).statistic
statistic[6] = stats.ks_2samp(probByYear['2011'], probByYear['2014']).statistic
statistic[7] = stats.ks_2samp(probByYear['2012'], probByYear['2013']).statistic
statistic[8] = stats.ks_2samp(probByYear['2012'], probByYear['2014']).statistic
statistic[9] = stats.ks_2samp(probByYear['2013'], probByYear['2014']).statistic
statistic
# Out:
# array([ 0.07480315,  0.04724409,  0.07874016,  0.06692913,  0.08661417,
#         0.10629921,  0.05511811,  0.07086614,  0.07480315,  0.09055118])

# %%
statistic.mean()
# Out:
# 0.075196850393700804

# %%
pvalue = np.zeros(10)
pvalue[0] = stats.ks_2samp(probByYear['2010'], probByYear['2011']).pvalue
pvalue[1] = stats.ks_2samp(probByYear['2010'], probByYear['2012']).pvalue
pvalue[2] = stats.ks_2samp(probByYear['2010'], probByYear['2013']).pvalue
pvalue[3] = stats.ks_2samp(probByYear['2010'], probByYear['2014']).pvalue
pvalue[4] = stats.ks_2samp(probByYear['2011'], probByYear['2012']).pvalue
pvalue[5] = stats.ks_2samp(probByYear['2011'], probByYear['2013']).pvalue
pvalue[6] = stats.ks_2samp(probByYear['2011'], probByYear['2014']).pvalue
pvalue[7] = stats.ks_2samp(probByYear['2012'], probByYear['2013']).pvalue
pvalue[8] = stats.ks_2samp(probByYear['2012'], probByYear['2014']).pvalue
pvalue[9] = stats.ks_2samp(probByYear['2013'], probByYear['2014']).pvalue
pvalue
# Out:
# array([ 0.46123387,  0.933853  ,  0.39608918,  0.6054357 ,  0.28382826,
#         0.10608061,  0.8247416 ,  0.53147885,  0.46123387,  0.23705982])

# %%
pvalue.mean()
# Out:
# 0.48410347674918575

# %%
ks_results = stats.kstest(company, cdf='norm')
ks_results
# Out:
# KstestResult(statistic=0.48168460940644214, pvalue=0.0)

# %% [markdown]
# ##### Анализ по объему:

# %%
company = dataVol["FP.PA"]
company
# Out:
# Date
# 2014-12-31     1357217.0
# 2014-12-30     5006078.0
# 2014-12-29     4842201.0
# 2014-12-24      984969.0
# 2014-12-23     5638668.0
# 2014-12-22     7715224.0
# 2014-12-19    18774080.0
# 2014-12-18    12546526.0
# 2014-12-17    11967934.0
# 2014-12-16    19984005.0
# 2014-12-15    11804036.0
# 2014-12-12     8676170.0
# 2014-12-11     8572086.0
# 2014-12-10     7857409.0
# 2014-12-09    11288951.0
# 2014-12-08     5302520.0
# 2014-12-05     8313523.0
# 2014-12-04     9967345.0
# 2014-12-03     7101955.0
# 2014-12-02    10407558.0
# 2014-12-01     8064178.0
# 2014-11-28    12596104.0
# 2014-11-27     8968304.0
# 2014-11-26     4992653.0
# 2014-11-25     6561112.0
# 2014-11-24     7296130.0
# 2014-11-21    11177812.0
# 2014-11-20     5670863.0
# 2014-11-19     3540461.0
# 2014-11-18     5325207.0
#                  ...
# 2010-02-12     7125154.0
# 2010-02-11    10466203.0
# 2010-02-10     8745859.0
# 2010-02-09     7817618.0
# 2010-02-08     7206580.0
# 2010-02-05    13653747.0
# 2010-02-04     7310050.0
# 2010-02-03     5711112.0
# 2010-02-02     8531488.0
# 2010-02-01     5717503.0
# 2010-01-29     7733803.0
# 2010-01-28     8276835.0
# 2010-01-27     7476841.0
# 2010-01-26     6908671.0
# 2010-01-25     5894241.0
# 2010-01-22     6440082.0
# 2010-01-21     6328808.0
# 2010-01-20     5858512.0
# 2010-01-19     5606988.0
# 2010-01-18     3403397.0
# 2010-01-15    10393180.0
# 2010-01-14     6024440.0
# 2010-01-13     6540221.0
# 2010-01-12     6145662.0
# 2010-01-11     5020707.0
# 2010-01-08     4626382.0
# 2010-01-07     4265108.0
# 2010-01-06     4721098.0
# 2010-01-05     9758572.0
# 2010-01-04     5255369.0
# Name: FP.PA, Length: 1278, dtype: float64

# %%
company.plot(figsize=(12,6))

# %%
company.resample('6W', how='mean').plot(figsize=(12,6))
# Out:
# C:\Users\maks_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
# how in .resample() is deprecated
# the new syntax is .resample(...).mean()

# %%
company.hist()

# %%
volByYear = DataFrame()
a = company['2010']
a.drop(a.head(2).index,inplace=True)
volByYear['2010'] = a.values
a = company['2011']
a.drop(a.head(3).index,inplace=True)
volByYear['2011'] = a.values
a = company['2012']
volByYear['2012'] = a.values
a = company['2013']
a.drop(a.head(1).index,inplace=True)
volByYear['2013'] = a.values
a = company['2014']
a.drop(a.head(2).index,inplace=True)
volByYear['2014'] = a.values
volByYear
# Out:
#            2010        2011        2012        2013        2014
# 0     2046653.0   2082367.0   3015559.0   3112369.0   4842201.0
# 1     3503336.0   3841537.0   4387748.0   4468518.0    984969.0
# 2     2442370.0   4420363.0   9480467.0    735234.0   5638668.0
# 3     3727692.0   5003341.0   5085931.0   3991218.0   7715224.0
# 4     5235592.0   8647528.0   4352863.0  23623961.0  18774080.0
# 5     4531202.0   7733976.0   4968258.0   7240881.0  12546526.0
# 6     9938878.0  12579019.0   4290472.0   5269632.0  11967934.0
# 7     5564878.0   5085896.0   4654117.0   4501474.0  19984005.0
# 8     5801349.0   6675564.0   4081820.0   6337048.0  11804036.0
# 9     6456757.0   6569786.0   4368210.0   4153270.0   8676170.0
# 10    7424276.0   5216716.0   4736839.0   4812976.0   8572086.0
# 11    4145224.0   6810240.0   3642647.0   4773053.0   7857409.0
# 12    6000477.0   7942056.0   4963217.0   4971230.0  11288951.0
# 13    6049970.0   5507037.0   4898770.0   3467473.0   5302520.0
# 14    7655136.0   4530664.0   4036178.0   4623171.0   8313523.0
# 15    5850594.0   4983129.0   3399852.0   5593124.0   9967345.0
# 16    5837497.0   5188318.0   4184773.0   5637525.0   7101955.0
# 17   10728516.0   5204001.0   5440885.0   4759563.0  10407558.0
# 18    7597503.0  10180438.0   4122676.0   3170643.0   8064178.0
# 19    9695185.0   4478810.0   3870471.0   3051084.0  12596104.0
# 20    8036291.0   7173010.0   5000742.0   2387984.0   8968304.0
# 21    6665782.0   6691616.0   2867097.0   4405426.0   4992653.0
# 22    4255130.0   6837824.0   2801347.0   3966706.0   6561112.0
# 23    6565529.0   5949771.0   2107179.0   3101906.0   7296130.0
# 24    6733133.0   4367278.0   3013753.0   3362152.0  11177812.0
# 25    5228633.0   5734713.0   3418311.0   3057021.0   5670863.0
# 26    5958373.0   5656024.0   5394320.0   2864883.0   3540461.0
# 27    6342693.0   5236736.0   5927515.0   3398327.0   5325207.0
# 28    5939878.0   5455819.0   3549203.0   3575324.0   4878557.0
# 29    9190833.0   5645756.0   4438875.0   3753160.0   4961687.0
# ..          ...         ...         ...         ...         ...
# 224   7125154.0   5198496.0   4892934.0   4485462.0   5064734.0
# 225  10466203.0   6117478.0   5086784.0   4141133.0   3997637.0
# 226   8745859.0   5326776.0   3817064.0   4851318.0   3332127.0
# 227   7817618.0   5242954.0   3729460.0   5377081.0   6649012.0
# 228   7206580.0   5955718.0   4089552.0   5048713.0   6065581.0
# 229  13653747.0   4440367.0   6091689.0   4379289.0   4590454.0
# 230   7310050.0   6060398.0   6000742.0   6073779.0   5689677.0
# 231   5711112.0   6258028.0   6935216.0   4323932.0   4068706.0
# 232   8531488.0   9912401.0   5539065.0   6875297.0   6182909.0
# 233   5717503.0   8246057.0   6854575.0   5751960.0   4689000.0
# 234   7733803.0   6086858.0   6545072.0   4727889.0   5891111.0
# 235   8276835.0   6184377.0   5574723.0   2989202.0   5088675.0
# 236   7476841.0   6120663.0   4528548.0   3420231.0   5364467.0
# 237   6908671.0   6078589.0   5561564.0   2654389.0   6362201.0
# 238   5894241.0   5557043.0   5405938.0   2612949.0   3819065.0
# 239   6440082.0  11626592.0  10580756.0   2522763.0   2607371.0
# 240   6328808.0   7440539.0   6727012.0   1691022.0   3050447.0
# 241   5858512.0   6248436.0   6291563.0   4796723.0   2511873.0
# 242   5606988.0   4913070.0   6482304.0   3498234.0   6809977.0
# 243   3403397.0   3732795.0   5380275.0   3036350.0   3290740.0
# 244  10393180.0   6910541.0   6972184.0   4311762.0   4489833.0
# 245   6024440.0   7938297.0   7741035.0   3061695.0   4415035.0
# 246   6540221.0   7169484.0   7689616.0   3145847.0   3303305.0
# 247   6145662.0   6044473.0   6457537.0   3608802.0   3745864.0
# 248   5020707.0   6288632.0   3466969.0   3292952.0   3216463.0
# 249   4626382.0   6299660.0   4258973.0   2661710.0   4347377.0
# 250   4265108.0   6364463.0   4330754.0   4191402.0   2794669.0
# 251   4721098.0   5428379.0   4408761.0   3317539.0   2558819.0
# 252   9758572.0   8291464.0   5327004.0   2898938.0   2084652.0
# 253   5255369.0   5532513.0   4088772.0   6709163.0   4721748.0
#
# [254 rows x 5 columns]

# %%
corrVol = volByYear.corr(method='pearson')
corrVol
# Out:
#           2010      2011      2012      2013      2014
# 2010  1.000000  0.058348  0.140351 -0.048686 -0.055438
# 2011  0.058348  1.000000 -0.044355  0.064437  0.082854
# 2012  0.140351 -0.044355  1.000000  0.063399 -0.148965
# 2013 -0.048686  0.064437  0.063399  1.000000  0.289081
# 2014 -0.055438  0.082854 -0.148965  0.289081  1.000000

# %%
plt.figure(figsize = (5,5))
sns.heatmap(corrVol, annot=True, fmt=".4f", center=0);

# %%
corrUniq = np.zeros(10)
corrUniq[0] = corrVol['2010']['2011']
corrUniq[1] = corrVol['2010']['2012']
corrUniq[2] = corrVol['2010']['2013']
corrUniq[3] = corrVol['2010']['2014']
corrUniq[4] = corrVol['2011']['2012']
corrUniq[5] = corrVol['2011']['2013']
corrUniq[6] = corrVol['2011']['2014']
corrUniq[7] = corrVol['2012']['2013']
corrUniq[8] = corrVol['2012']['2014']
corrUniq[9] = corrVol['2013']['2014']
corrUniq
# Out:
# array([ 0.05834763,  0.14035095, -0.04868551, -0.05543785, -0.04435536,
#         0.06443723,  0.08285431,  0.06339911, -0.14896503,  0.28908131])

# %%
corrUniq.mean()
# Out:
# 0.04010267916978847

# %%
statistic = np.zeros(10)
statistic[0] = stats.ks_2samp(volByYear['2010'], volByYear['2011']).statistic
statistic[1] = stats.ks_2samp(volByYear['2010'], volByYear['2012']).statistic
statistic[2] = stats.ks_2samp(volByYear['2010'], volByYear['2013']).statistic
statistic[3] = stats.ks_2samp(volByYear['2010'], volByYear['2014']).statistic
statistic[4] = stats.ks_2samp(volByYear['2011'], volByYear['2012']).statistic
statistic[5] = stats.ks_2samp(volByYear['2011'], volByYear['2013']).statistic
statistic[6] = stats.ks_2samp(volByYear['2011'], volByYear['2014']).statistic
statistic[7] = stats.ks_2samp(volByYear['2012'], volByYear['2013']).statistic
statistic[8] = stats.ks_2samp(volByYear['2012'], volByYear['2014']).statistic
statistic[9] = stats.ks_2samp(volByYear['2013'], volByYear['2014']).statistic
statistic
# Out:
# array([ 0.05905512,  0.33070866,  0.53149606,  0.35826772,  0.32283465,
#         0.52755906,  0.35433071,  0.26771654,  0.08267717,  0.22834646])

# %%
statistic.mean()
# Out:
# 0.30629921259842519

# %%
pvalue = np.zeros(10)
pvalue[0] = stats.ks_2samp(volByYear['2010'], volByYear['2011']).pvalue
pvalue[1] = stats.ks_2samp(volByYear['2010'], volByYear['2012']).pvalue
pvalue[2] = stats.ks_2samp(volByYear['2010'], volByYear['2013']).pvalue
pvalue[3] = stats.ks_2samp(volByYear['2010'], volByYear['2014']).pvalue
pvalue[4] = stats.ks_2samp(volByYear['2011'], volByYear['2012']).pvalue
pvalue[5] = stats.ks_2samp(volByYear['2011'], volByYear['2013']).pvalue
pvalue[6] = stats.ks_2samp(volByYear['2011'], volByYear['2014']).pvalue
pvalue[7] = stats.ks_2samp(volByYear['2012'], volByYear['2013']).pvalue
pvalue[8] = stats.ks_2samp(volByYear['2012'], volByYear['2014']).pvalue
pvalue[9] = stats.ks_2samp(volByYear['2013'], volByYear['2014']).pvalue
pvalue
# Out:
# array([  7.55291447e-01,   9.05948687e-13,   2.61698806e-32,
#          6.51719661e-15,   3.45073754e-12,   7.73386241e-32,
#          1.35115859e-14,   1.62816924e-08,   3.36840689e-01,
#          2.60598623e-06])

# %%
pvalue.mean()
# Out:
# 0.10921347586714117

# %%
ks_results = stats.kstest(company, cdf='norm')
ks_results
# Out:
# KstestResult(statistic=0.99921752738654146, pvalue=0.0)

# %% [markdown]
# ### Функция для анализа всех компаний по *доходностям*

# %%
from scipy.stats import ttest_ind as tt

def analisysProb(companyName):
    print("\n",companyName)
    company = dataProb[companyName]
    probByYear = DataFrame()
    a = company['2010']
    a.drop(a.head(1).index,inplace=True)
    probByYear['2010'] = a.values
    a = company['2011']
    a.drop(a.head(3).index,inplace=True)
    probByYear['2011'] = a.values
    a = company['2012']
    probByYear['2012'] = a.values
    a = company['2013']
    a.drop(a.head(1).index,inplace=True)
    probByYear['2013'] = a.values
    a = company['2014']
    a.drop(a.head(2).index,inplace=True)
    probByYear['2014'] = a.values
    print("Проверка на независимость:")
    corr = probByYear.corr(method='pearson')
    corrUniq = np.zeros(10)
    corrUniq[0] = corr['2010']['2011']
    corrUniq[1] = corr['2010']['2012']
    corrUniq[2] = corr['2010']['2013']
    corrUniq[3] = corr['2010']['2014']
    corrUniq[4] = corr['2011']['2012']
    corrUniq[5] = corr['2011']['2013']
    corrUniq[6] = corr['2011']['2014']
    corrUniq[7] = corr['2012']['2013']
    corrUniq[8] = corr['2012']['2014']
    corrUniq[9] = corr['2013']['2014']
    print("\tcorr mean = ", corrUniq.mean())
    print("Проверка на одинаковую распределенность:")
    statistic = np.zeros(10)
    statistic[0] = stats.ks_2samp(probByYear['2010'], probByYear['2011']).statistic
    statistic[1] = stats.ks_2samp(probByYear['2010'], probByYear['2012']).statistic
    statistic[2] = stats.ks_2samp(probByYear['2010'], probByYear['2013']).statistic
    statistic[3] = stats.ks_2samp(probByYear['2010'], probByYear['2014']).statistic
    statistic[4] = stats.ks_2samp(probByYear['2011'], probByYear['2012']).statistic
    statistic[5] = stats.ks_2samp(probByYear['2011'], probByYear['2013']).statistic
    statistic[6] = stats.ks_2samp(probByYear['2011'], probByYear['2014']).statistic
    statistic[7] = stats.ks_2samp(probByYear['2012'], probByYear['2013']).statistic
    statistic[8] = stats.ks_2samp(probByYear['2012'], probByYear['2014']).statistic
    statistic[9] = stats.ks_2samp(probByYear['2013'], probByYear['2014']).statistic
    print("\tstatistic = ", statistic.mean())
    pvalue = np.zeros(10)
    pvalue[0] = stats.ks_2samp(probByYear['2010'], probByYear['2011']).pvalue
    pvalue[1] = stats.ks_2samp(probByYear['2010'], probByYear['2012']).pvalue
    pvalue[2] = stats.ks_2samp(probByYear['2010'], probByYear['2013']).pvalue
    pvalue[3] = stats.ks_2samp(probByYear['2010'], probByYear['2014']).pvalue
    pvalue[4] = stats.ks_2samp(probByYear['2011'], probByYear['2012']).pvalue
    pvalue[5] = stats.ks_2samp(probByYear['2011'], probByYear['2013']).pvalue
    pvalue[6] = stats.ks_2samp(probByYear['2011'], probByYear['2014']).pvalue
    pvalue[7] = stats.ks_2samp(probByYear['2012'], probByYear['2013']).pvalue
    pvalue[8] = stats.ks_2samp(probByYear['2012'], probByYear['2014']).pvalue
    pvalue[9] = stats.ks_2samp(probByYear['2013'], probByYear['2014']).pvalue
    print("\tp-value = ", pvalue.mean())
    print("Тест Колмогорова-Смирнова:")
    ks_results = stats.kstest(company, cdf='norm')
    print("\tstatistic = ", ks_results.statistic)
    print("\tp=value = ", ks_results.pvalue)
    print("Тест на распределение Стьюдента:")
    a = np.random.standard_t(1, size=254)
    print("\tp=value = ", tt(company, a).pvalue)

# %%
names = dataProb.columns
names
# Out:
# Index(['ACA.PA', 'AF.PA', 'AI.PA', 'AIR.PA', 'ALO.PA', 'ALT.PA', 'BN.PA',
#        'BNP.PA', 'CNP.PA', 'CS.PA', 'DG.PA', 'FP.PA', 'GLE.PA', 'ING.PA',
#        'KN.PA', 'LI.PA', 'LR.PA', 'MAU.PA', 'ORA.PA', 'RNO.PA', 'RXL.PA',
#        'SAF.PA', 'SCR.PA', 'SEV.PA', 'STM.PA', 'SU.PA', 'UG.PA', 'VIE.PA',
#        'VIV.PA', 'VK.PA', 'ZC.PA'],
#       dtype='object')

# %%
for name in names:
    analisysProb(name)
# Out:
#  ACA.PA
# Проверка на независимость:
# 	corr mean =  -0.0207662861554
# Проверка на одинаковую распределенность:
# 	statistic =  0.122047244094
# 	p-value =  0.160645500517
# Тест Колмогорова-Смирнова:
# 	statistic =  0.461905936926
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.00443042934331
#
#  AF.PA
# Проверка на независимость:
# 	corr mean =  -0.0211519224104
# Проверка на одинаковую распределенность:
# 	statistic =  0.100787401575
# 	p-value =  0.202827715149
# Тест Колмогорова-Смирнова:
# 	statistic =  0.463553905031
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.00136309562311
#
#  AI.PA
# Проверка на независимость:
# 	corr mean =  0.00410519121053
# Проверка на одинаковую распределенность:
# 	statistic =  0.0842519685039
# 	p-value =  0.432989747223
# Тест Колмогорова-Смирнова:
# 	statistic =  0.483640888202
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.125728532547
#
#  AIR.PA
# Проверка на независимость:
# 	corr mean =  0.00856870450387
# Проверка на одинаковую распределенность:
# 	statistic =  0.0929133858268
# 	p-value =  0.316622716942
# Тест Колмогорова-Смирнова:
# 	statistic =  0.47309444678
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.454295581251
#
#  ALO.PA
# Проверка на независимость:
# 	corr mean =  -0.00734580418252
# Проверка на одинаковую распределенность:
# 	statistic =  0.117716535433
# 	p-value =  0.162470264335
# Тест Колмогорова-Смирнова:
# 	statistic =  0.468267354169
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.903202162768
#
#  ALT.PA
# Проверка на независимость:
# 	corr mean =  0.01466930625
# Проверка на одинаковую распределенность:
# 	statistic =  0.128346456693
# 	p-value =  0.101823550574
# Тест Колмогорова-Смирнова:
# 	statistic =  0.467042555293
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.0283380487344
#
#  BN.PA
# Проверка на независимость:
# 	corr mean =  0.0304058652146
# Проверка на одинаковую распределенность:
# 	statistic =  0.0732283464567
# 	p-value =  0.53053353916
# Тест Колмогорова-Смирнова:
# 	statistic =  0.482410877658
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.340423946787
#
#  BNP.PA
# Проверка на независимость:
# 	corr mean =  -0.019212207655
# Проверка на одинаковую распределенность:
# 	statistic =  0.119291338583
# 	p-value =  0.123476966628
# Тест Колмогорова-Смирнова:
# 	statistic =  0.464610333697
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.594063402673
#
#  CNP.PA
# Проверка на независимость:
# 	corr mean =  0.00499470941317
# Проверка на одинаковую распределенность:
# 	statistic =  0.113385826772
# 	p-value =  0.167294732192
# Тест Колмогорова-Смирнова:
# 	statistic =  0.474336432763
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.000207205631213
#
#  CS.PA
# Проверка на независимость:
# 	corr mean =  -0.0183050244261
# Проверка на одинаковую распределенность:
# 	statistic =  0.126771653543
# 	p-value =  0.111065665018
# Тест Колмогорова-Смирнова:
# 	statistic =  0.46654682893
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.595929111715
#
#  DG.PA
# Проверка на независимость:
# 	corr mean =  -0.00607914942995
# Проверка на одинаковую распределенность:
# 	statistic =  0.106299212598
# 	p-value =  0.230337698742
# Тест Колмогорова-Смирнова:
# 	statistic =  0.475583944218
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.00869272127
#
#  FP.PA
# Проверка на независимость:
# 	corr mean =  -0.0357589152946
# Проверка на одинаковую распределенность:
# 	statistic =  0.0751968503937
# 	p-value =  0.484103476749
# Тест Колмогорова-Смирнова:
# 	statistic =  0.481684609406
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.0723884913366
#
#  GLE.PA
# Проверка на независимость:
# 	corr mean =  -0.0291144403654
# Проверка на одинаковую распределенность:
# 	statistic =  0.124803149606
# 	p-value =  0.0839995534714
# Тест Колмогорова-Смирнова:
# 	statistic =  0.458252707728
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.00298384683126
#
#  ING.PA
# Проверка на независимость:
# 	corr mean =  -0.00361786407132
# Проверка на одинаковую распределенность:
# 	statistic =  0.0925196850394
# 	p-value =  0.332382725545
# Тест Колмогорова-Смирнова:
# 	statistic =  0.477103382192
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.357140066859
#
#  KN.PA
# Проверка на независимость:
# 	corr mean =  -0.0221208956343
# Проверка на одинаковую распределенность:
# 	statistic =  0.113779527559
# 	p-value =  0.174664629115
# Тест Колмогорова-Смирнова:
# 	statistic =  0.463706147066
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.026053810915
#
#  LI.PA
# Проверка на независимость:
# 	corr mean =  -0.00414562171303
# Проверка на одинаковую распределенность:
# 	statistic =  0.102755905512
# 	p-value =  0.240788497335
# Тест Колмогорова-Смирнова:
# 	statistic =  0.477306059741
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.0286471545545
#
#  LR.PA
# Проверка на независимость:
# 	corr mean =  0.00607508772479
# Проверка на одинаковую распределенность:
# 	statistic =  0.0968503937008
# 	p-value =  0.248195319897
# Тест Колмогорова-Смирнова:
# 	statistic =  0.478276136069
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.89133584177
#
#  MAU.PA
# Проверка на независимость:
# 	corr mean =  0.0144055328669
# Проверка на одинаковую распределенность:
# 	statistic =  0.124015748031
# 	p-value =  0.132998731275
# Тест Колмогорова-Смирнова:
# 	statistic =  0.470736907762
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.00168479499703
#
#  ORA.PA
# Проверка на независимость:
# 	corr mean =  -0.00582323772082
# Проверка на одинаковую распределенность:
# 	statistic =  0.112598425197
# 	p-value =  0.191482998004
# Тест Колмогорова-Смирнова:
# 	statistic =  0.478545304368
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.00193021233984
#
#  RNO.PA
# Проверка на независимость:
# 	corr mean =  0.011789948686
# Проверка на одинаковую распределенность:
# 	statistic =  0.0933070866142
# 	p-value =  0.27582418161
# Тест Колмогорова-Смирнова:
# 	statistic =  0.469767159853
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.0379424107137
#
#  RXL.PA
# Проверка на независимость:
# 	corr mean =  -0.00468496895873
# Проверка на одинаковую распределенность:
# 	statistic =  0.12125984252
# 	p-value =  0.14771236788
# Тест Колмогорова-Смирнова:
# 	statistic =  0.47365026762
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.0786046478912
#
#  SAF.PA
# Проверка на независимость:
# 	corr mean =  0.00118396383654
# Проверка на одинаковую распределенность:
# 	statistic =  0.123622047244
# 	p-value =  0.142542010185
# Тест Колмогорова-Смирнова:
# 	statistic =  0.472397959901
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.037941737342
#
#  SCR.PA
# Проверка на независимость:
# 	corr mean =  -0.00112756261655
# Проверка на одинаковую распределенность:
# 	statistic =  0.108267716535
# 	p-value =  0.327612109594
# Тест Колмогорова-Смирнова:
# 	statistic =  0.476604792167
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.0561330282364
#
#  SEV.PA
# Проверка на независимость:
# 	corr mean =  0.0080358114879
# Проверка на одинаковую распределенность:
# 	statistic =  0.102755905512
# 	p-value =  0.222716177116
# Тест Колмогорова-Смирнова:
# 	statistic =  0.476944311791
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.309453843224
#
#  STM.PA
# Проверка на независимость:
# 	corr mean =  0.0231274283051
# Проверка на одинаковую распределенность:
# 	statistic =  0.106692913386
# 	p-value =  0.248346733217
# Тест Колмогорова-Смирнова:
# 	statistic =  0.466662109913
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.844536100658
#
#  SU.PA
# Проверка на независимость:
# 	corr mean =  -0.0175381093834
# Проверка на одинаковую распределенность:
# 	statistic =  0.109448818898
# 	p-value =  0.207207461542
# Тест Колмогорова-Смирнова:
# 	statistic =  0.471298917049
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.059708020665
#
#  UG.PA
# Проверка на независимость:
# 	corr mean =  0.0167981582673
# Проверка на одинаковую распределенность:
# 	statistic =  0.101968503937
# 	p-value =  0.264219724882
# Тест Колмогорова-Смирнова:
# 	statistic =  0.463347028698
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.126824324691
#
#  VIE.PA
# Проверка на независимость:
# 	corr mean =  -0.0251340696284
# Проверка на одинаковую распределенность:
# 	statistic =  0.118897637795
# 	p-value =  0.149242205618
# Тест Колмогорова-Смирнова:
# 	statistic =  0.47076206547
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.0921423209347
#
#  VIV.PA
# Проверка на независимость:
# 	corr mean =  0.0173834429352
# Проверка на одинаковую распределенность:
# 	statistic =  0.104330708661
# 	p-value =  0.2349302639
# Тест Колмогорова-Смирнова:
# 	statistic =  0.479552934058
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.00403637326051
#
#  VK.PA
# Проверка на независимость:
# 	corr mean =  0.0122319909869
# Проверка на одинаковую распределенность:
# 	statistic =  0.100393700787
# 	p-value =  0.183922354168
# Тест Колмогорова-Смирнова:
# 	statistic =  0.469194366246
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  0.257610380015
#
#  ZC.PA
# Проверка на независимость:
# 	corr mean =  0.0426191895109
# Проверка на одинаковую распределенность:
# 	statistic =  0.120472440945
# 	p-value =  0.21052335031
# Тест Колмогорова-Смирнова:
# 	statistic =  0.476531115557
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  5.30366625202e-05

# %% [markdown]
# ### Функция для анализа всех компаний по *объему продаж*

# %%
def analisysVol(companyName):
    print("\n",companyName)
    company = dataVol[companyName]
    volByYear = DataFrame()
    a = company['2010']
    a.drop(a.head(2).index,inplace=True)
    volByYear['2010'] = a.values
    a = company['2011']
    a.drop(a.head(3).index,inplace=True)
    volByYear['2011'] = a.values
    a = company['2012']
    volByYear['2012'] = a.values
    a = company['2013']
    a.drop(a.head(1).index,inplace=True)
    volByYear['2013'] = a.values
    a = company['2014']
    a.drop(a.head(2).index,inplace=True)
    volByYear['2014'] = a.values
    print("Проверка на независимость:")
    corrVol = volByYear.corr(method='pearson')
    corrUniq = np.zeros(10)
    corrUniq[0] = corrVol['2010']['2011']
    corrUniq[1] = corrVol['2010']['2012']
    corrUniq[2] = corrVol['2010']['2013']
    corrUniq[3] = corrVol['2010']['2014']
    corrUniq[4] = corrVol['2011']['2012']
    corrUniq[5] = corrVol['2011']['2013']
    corrUniq[6] = corrVol['2011']['2014']
    corrUniq[7] = corrVol['2012']['2013']
    corrUniq[8] = corrVol['2012']['2014']
    corrUniq[9] = corrVol['2013']['2014']
    print("\tcorr mean = ", corrUniq.mean())
    print("Проверка на одинаковую распределенность:")
    statistic = np.zeros(10)
    statistic[0] = stats.ks_2samp(volByYear['2010'], volByYear['2011']).statistic
    statistic[1] = stats.ks_2samp(volByYear['2010'], volByYear['2012']).statistic
    statistic[2] = stats.ks_2samp(volByYear['2010'], volByYear['2013']).statistic
    statistic[3] = stats.ks_2samp(volByYear['2010'], volByYear['2014']).statistic
    statistic[4] = stats.ks_2samp(volByYear['2011'], volByYear['2012']).statistic
    statistic[5] = stats.ks_2samp(volByYear['2011'], volByYear['2013']).statistic
    statistic[6] = stats.ks_2samp(volByYear['2011'], volByYear['2014']).statistic
    statistic[7] = stats.ks_2samp(volByYear['2012'], volByYear['2013']).statistic
    statistic[8] = stats.ks_2samp(volByYear['2012'], volByYear['2014']).statistic
    statistic[9] = stats.ks_2samp(volByYear['2013'], volByYear['2014']).statistic
    print("\tstatistic = ", statistic.mean())
    pvalue = np.zeros(10)
    pvalue[0] = stats.ks_2samp(volByYear['2010'], volByYear['2011']).pvalue
    pvalue[1] = stats.ks_2samp(volByYear['2010'], volByYear['2012']).pvalue
    pvalue[2] = stats.ks_2samp(volByYear['2010'], volByYear['2013']).pvalue
    pvalue[3] = stats.ks_2samp(volByYear['2010'], volByYear['2014']).pvalue
    pvalue[4] = stats.ks_2samp(volByYear['2011'], volByYear['2012']).pvalue
    pvalue[5] = stats.ks_2samp(volByYear['2011'], volByYear['2013']).pvalue
    pvalue[6] = stats.ks_2samp(volByYear['2011'], volByYear['2014']).pvalue
    pvalue[7] = stats.ks_2samp(volByYear['2012'], volByYear['2013']).pvalue
    pvalue[8] = stats.ks_2samp(volByYear['2012'], volByYear['2014']).pvalue
    pvalue[9] = stats.ks_2samp(volByYear['2013'], volByYear['2014']).pvalue    
    print("\tp-value = ", pvalue.mean())
    print("Тест Колмогорова-Смирнова:")
    ks_results = stats.kstest(company, cdf='norm')
    print("\tstatistic = ", ks_results.statistic)
    print("\tp=value = ", ks_results.pvalue)
    print("Тест на распределение Стьюдента:")
    a = np.random.standard_t(1, size=254)
    print("\tp=value = ", tt(company, a).pvalue)

# %%
names = dataVol.columns
names
# Out:
# Index(['ACA.PA', 'AF.PA', 'AI.PA', 'AIR.PA', 'ALO.PA', 'ALT.PA', 'BN.PA',
#        'BNP.PA', 'BOL.PA', 'CNP.PA', 'CS.PA', 'DG.PA', 'FP.PA', 'GLE.PA',
#        'ING.PA', 'KN.PA', 'LI.PA', 'LR.PA', 'MAU.PA', 'ORA.PA', 'RNO.PA',
#        'RXL.PA', 'SAF.PA', 'SCR.PA', 'SEV.PA', 'STM.PA', 'SU.PA', 'UG.PA',
#        'VIE.PA', 'VIV.PA', 'VK.PA', 'ZC.PA'],
#       dtype='object')

# %%
for name in names:
    analisysVol(name)
# Out:
#  ACA.PA
# Проверка на независимость:
# 	corr mean =  0.00713440874082
# Проверка на одинаковую распределенность:
# 	statistic =  0.379921259843
# 	p-value =  0.00334961010706
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  6.26457392367e-118
#
#  AF.PA
# Проверка на независимость:
# 	corr mean =  0.0394050249683
# Проверка на одинаковую распределенность:
# 	statistic =  0.254724409449
# 	p-value =  0.105644915809
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  2.93893239106e-139
#
#  AI.PA
# Проверка на независимость:
# 	corr mean =  0.0122656818788
# Проверка на одинаковую распределенность:
# 	statistic =  0.316929133858
# 	p-value =  0.0325685334729
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  6.9961760763e-200
#
#  AIR.PA
# Проверка на независимость:
# 	corr mean =  0.00744100383977
# Проверка на одинаковую распределенность:
# 	statistic =  0.236614173228
# 	p-value =  0.0476637407573
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  3.95425549795e-101
#
#  ALO.PA
# Проверка на независимость:
# 	corr mean =  0.116557654773
# Проверка на одинаковую распределенность:
# 	statistic =  0.208267716535
# 	p-value =  0.0304333607679
# Тест Колмогорова-Смирнова:
# 	statistic =  0.996870109546
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  7.03740734049e-80
#
#  ALT.PA
# Проверка на независимость:
# 	corr mean =  0.188371662161
# Проверка на одинаковую распределенность:
# 	statistic =  0.290157480315
# 	p-value =  0.00969086319609
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.77324604625e-75
#
#  BN.PA
# Проверка на независимость:
# 	corr mean =  0.101601048826
# Проверка на одинаковую распределенность:
# 	statistic =  0.253149606299
# 	p-value =  0.0946752301062
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.5404651499e-193
#
#  BNP.PA
# Проверка на независимость:
# 	corr mean =  0.0132880400448
# Проверка на одинаковую распределенность:
# 	statistic =  0.277559055118
# 	p-value =  0.0712039823015
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.36170952005e-156
#
#  BOL.PA
# Проверка на независимость:
# 	corr mean =  0.0203031943528
# Проверка на одинаковую распределенность:
# 	statistic =  0.315748031496
# 	p-value =  0.159139507519
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  3.80115073967e-07
#
#  CNP.PA
# Проверка на независимость:
# 	corr mean =  0.0148925030453
# Проверка на одинаковую распределенность:
# 	statistic =  0.236220472441
# 	p-value =  0.00574712068113
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.97958683855e-140
#
#  CS.PA
# Проверка на независимость:
# 	corr mean =  0.0279712217758
# Проверка на одинаковую распределенность:
# 	statistic =  0.324803149606
# 	p-value =  0.00292873822384
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.21401453465e-171
#
#  DG.PA
# Проверка на независимость:
# 	corr mean =  -0.0132280489689
# Проверка на одинаковую распределенность:
# 	statistic =  0.25157480315
# 	p-value =  0.0135913462294
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.0908180449e-195
#
#  FP.PA
# Проверка на независимость:
# 	corr mean =  0.0401026791698
# Проверка на одинаковую распределенность:
# 	statistic =  0.306299212598
# 	p-value =  0.109213475867
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.50458430131e-144
#
#  GLE.PA
# Проверка на независимость:
# 	corr mean =  -0.00131928700214
# Проверка на одинаковую распределенность:
# 	statistic =  0.264566929134
# 	p-value =  0.077746352191
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  2.14984933966e-168
#
#  ING.PA
# Проверка на независимость:
# 	corr mean =  0.0282172655786
# Проверка на одинаковую распределенность:
# 	statistic =  0.259842519685
# 	p-value =  0.0550960380578
# Тест Колмогорова-Смирнова:
# 	statistic =  0.998435054773
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  3.62038797114e-27
#
#  KN.PA
# Проверка на независимость:
# 	corr mean =  0.0820686058619
# Проверка на одинаковую распределенность:
# 	statistic =  0.253937007874
# 	p-value =  0.120119827345
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  9.984893918e-114
#
#  LI.PA
# Проверка на независимость:
# 	corr mean =  -0.0133239045758
# Проверка на одинаковую распределенность:
# 	statistic =  0.35157480315
# 	p-value =  0.0442945677823
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  3.28044559655e-115
#
#  LR.PA
# Проверка на независимость:
# 	corr mean =  0.0521283450509
# Проверка на одинаковую распределенность:
# 	statistic =  0.212598425197
# 	p-value =  0.0370077338996
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.74314628256e-103
#
#  MAU.PA
# Проверка на независимость:
# 	corr mean =  0.0217075945178
# Проверка на одинаковую распределенность:
# 	statistic =  0.326377952756
# 	p-value =  0.00677558189854
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  3.64313059247e-51
#
#  ORA.PA
# Проверка на независимость:
# 	corr mean =  0.0309693948735
# Проверка на одинаковую распределенность:
# 	statistic =  0.13031496063
# 	p-value =  0.102225194458
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.54399710119e-171
#
#  RNO.PA
# Проверка на независимость:
# 	corr mean =  0.0937010778645
# Проверка на одинаковую распределенность:
# 	statistic =  0.431496062992
# 	p-value =  0.0161491026823
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.50504040452e-145
#
#  RXL.PA
# Проверка на независимость:
# 	corr mean =  0.0225665455915
# Проверка на одинаковую распределенность:
# 	statistic =  0.331496062992
# 	p-value =  0.000913819585037
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  2.52892543912e-67
#
#  SAF.PA
# Проверка на независимость:
# 	corr mean =  0.0687243881216
# Проверка на одинаковую распределенность:
# 	statistic =  0.240551181102
# 	p-value =  0.0582372395932
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  4.94174895473e-129
#
#  SCR.PA
# Проверка на независимость:
# 	corr mean =  0.0968370876993
# Проверка на одинаковую распределенность:
# 	statistic =  0.205118110236
# 	p-value =  0.04466433095
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.42006385897e-107
#
#  SEV.PA
# Проверка на независимость:
# 	corr mean =  -0.00197435956701
# Проверка на одинаковую распределенность:
# 	statistic =  0.283464566929
# 	p-value =  0.00273606219781
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  4.79979811957e-146
#
#  STM.PA
# Проверка на независимость:
# 	corr mean =  0.0743938381537
# Проверка на одинаковую распределенность:
# 	statistic =  0.415354330709
# 	p-value =  0.0033152264927
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  7.05185486084e-143
#
#  SU.PA
# Проверка на независимость:
# 	corr mean =  0.0393912533167
# Проверка на одинаковую распределенность:
# 	statistic =  0.305511811024
# 	p-value =  0.0004949932481
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  5.42535105196e-188
#
#  UG.PA
# Проверка на независимость:
# 	corr mean =  0.0456298996541
# Проверка на одинаковую распределенность:
# 	statistic =  0.370866141732
# 	p-value =  0.0337027280494
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.13126756087e-98
#
#  VIE.PA
# Проверка на независимость:
# 	corr mean =  0.0274537921427
# Проверка на одинаковую распределенность:
# 	statistic =  0.361023622047
# 	p-value =  0.0161244082527
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.21931683578e-128
#
#  VIV.PA
# Проверка на независимость:
# 	corr mean =  0.0417553128361
# Проверка на одинаковую распределенность:
# 	statistic =  0.170078740157
# 	p-value =  0.0926906251818
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  8.19117623778e-188
#
#  VK.PA
# Проверка на независимость:
# 	corr mean =  0.0547373224895
# Проверка на одинаковую распределенность:
# 	statistic =  0.167716535433
# 	p-value =  0.253802690839
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  2.47321688199e-111
#
#  ZC.PA
# Проверка на независимость:
# 	corr mean =  0.108401941326
# Проверка на одинаковую распределенность:
# 	statistic =  0.366141732283
# 	p-value =  0.00676956626362
# Тест Колмогорова-Смирнова:
# 	statistic =  0.999217527387
# 	p=value =  0.0
# Тест на распределение Стьюдента:
# 	p=value =  1.09257037064e-90

# %% [markdown]
# # 5. Исследование зависимости между доходностями нескольких активов

# %% [markdown]
# Выбираем 2 конкретных компании и проводим для них анализ нужными методами

# %%
company1 = dataProb['MAU.PA']
company2 = dataProb['FP.PA']

# %% [markdown]
# ## Коэффициент корреляции

# %%
np.corrcoef(company1, company2)[0][1]
# Out:
# 0.50487408588702498

# %% [markdown]
# ## Линейная регрессия

# %%
company1_New = []
for n in company1:
    company1_New.append([n])

# %%
def RMSE(trueY, predictedY):
    return np.sqrt(mean_squared_error(trueY, predictedY))

# %%
regressionModel = linear_model.LinearRegression()
regressionModel.fit(company1_New, company2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# Оценка качества регрессии

# %%
predictedCompany2 = regressionModel.predict(company1_New)
coef = r2_score(company2, predictedCompany2)
err = RMSE(company2, predictedCompany2)
print("r2_score = ", coef)
print("RMSE = ", err)
# Out:
# r2_score =  0.2548978426
# RMSE =  0.0117024158124

# %%
regressionModel.coef_[0]
corX = np.linspace(-0.17, 0.1, 150)
corXNew = []
for n in corX:
    corXNew.append([n])
corY = regressionModel.predict(corXNew)

# %%
plt.plot(company1, company2, 'o', alpha = 0.3, color="red");
plt.plot(corX, corY, 'o', alpha = 0.8, color="green");

# %% [markdown]
# ## Таблица сопряженности признаков, тест Хи-квадрат

# %%
a = crosstab(company1, company2)
colsum = a.sum(axis=0)
colpct = a/colsum
cs1 = stats.chi2_contingency(a)
# chi-square value, p-value
print("Chi-square value = ", cs1[0])
print("P-value = ", cs1[1])
# Out:
# Chi-square value =  1583096.9
# P-value =  0.0363423733776

# %% [markdown]
# # 6. Исследование зависимости между доходностью и объемом продаж одного актива

# %% [markdown]
# Выбираем конкретную компанию и проводим для нее анализ нужными методами

# %% [markdown]
# ## Коэффициент корреляции

# %%
dataVol.drop(dataVol.tail(1).index,inplace=True)

# %%
com = "SEV.PA"
prob = dataProb[com].values
vol = dataVol[com].values

# %%
np.corrcoef(prob, vol)[0][1]
# Out:
# 0.014267802030307154

# %% [markdown]
# ## Линейная регрессия

# %%
prob_New = []
for n in prob:
    prob_New.append([n])

# %%
def RMSE(trueY, predictedY):
    return np.sqrt(mean_squared_error(trueY, predictedY))

# %%
regressionModel = linear_model.LinearRegression()
regressionModel.fit(prob_New, vol)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# Оценка качества регрессии

# %%
predictedVol = regressionModel.predict(prob_New)
coef = r2_score(vol, predictedVol)
err = RMSE(vol, predictedVol)
print("r2_score = ", coef)
print("RMSE = ", err)
# Out:
# r2_score =  0.000203570174776
# RMSE =  702288.494816

# %%
regressionModel.coef_[0]
corX = np.linspace(-0.09, 0.08, 150)
corXNew = []
for n in corX:
    corXNew.append([n])
corY = regressionModel.predict(corXNew)

# %%
plt.plot(prob, vol, 'o', alpha = 0.3, color="red");
plt.plot(corX, corY, 'o', alpha = 0.8, color="green");

# %% [markdown]
# ## Таблица сопряженности признаков, тест Хи-квадрат

# %%
a = crosstab(prob, vol)
colsum = a.sum(axis=0)
colpct = a/colsum
cs1 = stats.chi2_contingency(a)
# chi-square value, p-value
print("Chi-square value = ", cs1[0])
print("P-value = ", cs1[1])
# Out:
# Chi-square value =  1598804.0
# P-value =  0.241771546314
